# %% [markdown]
# <a href="https://colab.research.google.com/github/AnastasiaMoiseyev/STA2023_Fall_2022/blob/main/Anastasia_Stats_2023_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stats Notebook Lab #4

# %%
#Import libraries 
import numpy as np #imports numpy. to use numpy, use"np". i.e."np.random.randn"
import matplotlib.pyplot as plt  #imports matplotlib.pyplot. to use it, use "plt.plot(x,y,'r.')"

# %%
x = np.array([1,2,3,4])
#Arrays are Data Structures that can hold multiple values of the same type.

# %%
# population

# %%
np.sum(x) 
#The numpy. sum() function is available in the NumPy package of Python. 
#This function is used to compute the sum of all elements, the sum of each row, and the sum of each column of a given array. 
#Essentially, this sum ups the elements of an array, takes the elements within a ndarray, and adds them together.
# Out:
# 10

# %%
x.shape[0]
#x[0]. shape will give the Length of 1st row of an array. x. shape[0] will give the number of rows in an array.
# Out:
# 4

# %%
np.sum(x)/x.shape[0]
# Out:
# 2.5

# %%
def mean(x):
    return np.sum(x)/x.shape[0]

# %%
mean(x)
#The mean() function is used to calculate the mean/average of input values or data sets. 
#The mean() function accepts the list, tuple, or data-set containing numeric values as a parameter and returns the average of the data items.
# Out:
# 2.5

# %%
x
# Out:
# array([1, 2, 3, 4])

# %%
x - mean(x)
# Out:
# array([-1.5, -0.5,  0.5,  1.5])

# %%
(x - mean(x))**2
# Out:
# array([2.25, 0.25, 0.25, 2.25])

# %%
 def var(x):
    return mean((x - mean(x))**2)

# %%
def std(x):
    return np.sqrt(var(x))

# %%
mean(x)
# Out:
# 2.5

# %%
var(x)
#variance() method calculates the variance from a sample of data (from a population). 
#A large variance indicates that the data is spread out, - a small variance indicates that the data is clustered closely around the mean.
# Out:
# 1.25

# %%
std(x)
#std(), used to compute the standard deviation along the specified axis. 
#This function returns the standard deviation of the array elements. 
#The square root of the average square deviation (computed from the mean), is known as the standard deviation.
# Out:
# 1.118033988749895

# %% [markdown]
# ### Random Number Generator

# %% [markdown]
# $y=mx+b$

# %%
m = 75                 # multiplier
b = 74                 # increment
n = 65537              # modulus

# %%
x = 58      # seed value

# %%
X = np.zeros(50000,)

# %%
x = (m * x + b) % n

# %%
for i in range(X.shape[0]):

    x = (m * x + b) % n
    
    X[i] = x

# %%
X
# Out:
# array([ 4189., 52101., 40966., ..., 26762., 41114.,  3385.])

# %%
X /= np.max(X)

# %%
plt.plot(X[:100],'.') #The plot() function is used to draw points (markers) in a diagram. 
#By default, the plot() function draws a line from point to point. 
#The function takes parameters for specifying points in the diagram.

# %% [markdown]
# #Histogram
# #A histogram is a graph that shows the frequency of numerical data using rectangles. The height of a rectangle (the vertical axis) represents the distribution frequency of a variable (the amount, or how often that variable appears).

# %%
plt.hist(X); #The hist() function in pyplot module of matplotlib library is used to plot a histogram.

# %%
plt.hist(X,100);

# %%
X
# Out:
# array([0.06392004, 0.7950103 , 0.62510109, ..., 0.40836194, 0.62735943,
#        0.05165179])

# %%
X
# Out:
# array([0.06392004, 0.7950103 , 0.62510109, ..., 0.40836194, 0.62735943,
#        0.05165179])

# %%
X
# Out:
# array([0.06392004, 0.7950103 , 0.62510109, ..., 0.40836194, 0.62735943,
#        0.05165179])

# %% [markdown]
# ### Random Numbers

# %%
X = np.random.random(50000,) 
#random. random() is one of the functions for doing random sampling in numpy.

# %%
X
# Out:
# array([0.60921545, 0.26423238, 0.82197816, ..., 0.14278746, 0.43773385,
#        0.26840655])

# %%
plt.hist(X,100);  
#The hist() function in pyplot module of matplotlib library is used to plot a histogram.

# %%
np.random.random()
# Out:
# 0.56195093048398

# %%
r = np.random.random()

# %%
r
# Out:
# 0.23059775430526774

# %%
r = np.random.randint(1,10)

# %%
r
# Out:
# 8

# %%
r = np.random.randint(0,3,size=(1))

# %%
r[0]
# Out:
# 1

# %%
game = ['rock', 'paper', 'scissors']

# %%
game[r[0]]
# Out:
# 'paper'

# %%
p1 = np.random.randint(0,3,size=(1))[0]
p2 = np.random.randint(0,3,size=(1))[0]

# %%
p1,p2
# Out:
# (0, 2)

# %%
p1 = np.random.randint(0,3,size=(1))[0]
p2 = np.random.randint(0,3,size=(1))[0]
game[p1],game[p2]
# Out:
# ('scissors', 'rock')

# %%
import numpy as np

# %%
np.random.randn()
# Out:
# -2.4872535059891425

# %%
numbers  = np.random.randn(2,4)

# %%
numbers.shape
# Out:
# (2, 4)

# %%
numbers = numbers.reshape(-1) #Reshape mean changing the shape of an array

# %%
numbers.shape
# Out:
# (8,)

# %%
# numbers= np.array([1,2,2,3,3,3,4,4,4,4])

# %%
numbers = np.random.randn(100000,)

# %%
numbers.shape
# Out:
# (100000,)

# %%
plt.hist(numbers,100); #The hist() function in pyplot module of matplotlib library is used to plot a histogram.

# %%
numbers = np.random.rand(1000000,) #The np.random.rand() function creates an array of specified shape and fills it with random values.

# %%
plt.hist(numbers,100); #The hist() function in pyplot module of matplotlib library is used to plot a histogram.

# %%
np.random.seed(12345)
data = np.random.randn(2, 100)

plt.figure(1, figsize=(9, 9))


plt.subplot(2,2,1)
plt.hist(data[0])

plt.subplot(2,2,2)
plt.scatter(data[0], data[1])

plt.subplot(2,2,3)
plt.plot(data[0], data[1])

plt.subplot(2,2,4)
plt.hist2d(data[0], data[1])

plt.show()

# %% [markdown]
# Normal Dist Data

# %%
x = 50*np.random.randn(10000)

# %%
plt.hist(x); #The hist() function in pyplot module of matplotlib library is used to plot a histogram.

# %%
x = np.random.rand(1000,) #The np.random.rand() function creates an array of specified shape and fills it with random values.

# %%
plt.hist(x**2); #The hist() function in pyplot module of matplotlib library is used to plot a histogram.

# %%
mu = 100  # mean of distribution
sigma = 15  # standard deviation of distribution
x = mu + sigma * np.random.randn(10000)

# %%
n,bins,patches = plt.hist(x)

# %%
bins #bins -optional parameter contains integer or sequence or strings
# Out:
# array([ 47.67401067,  58.67171625,  69.66942183,  80.66712741,
#         91.664833  , 102.66253858, 113.66024416, 124.65794974,
#        135.65565532, 146.65336091, 157.65106649])

# %%
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(y)

# %%
num_bins = 50
n,bins,patches = plt.hist(x, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)

# %%
def mean(x):
    return np.sum(x)/x.shape[0]

# %%
def var(x):
    return mean((x - mean(x))**2)

# %%
def std(x):
    return np.sqrt(var(x))

# %%
mean(x) 
#mean() method calculates the mean (average) of the given data set.
# Out:
# 100.09627243164132

# %%
std(x) 
#std(), used to compute the standard deviation along the specified axis.
# Out:
# 15.036672317552396

# %% [markdown]
# # Normal Random Number Generator

# %%
#CDF PDF

# %%
x = np.linspace(-10,10,100)
y = 2.71**(-x**2)
plt.plot(x,y)

# %% [markdown]
# $e^{-x^2}$

# %% [markdown]
# ![alt text](https://wikimedia.org/api/rest_v1/media/math/render/svg/4abaca87a10ecfa77b5a205056523706fe6c9c3f)

# %%
def normal_pdf(x,mu,sigma):
  
  return (1/(np.sqrt(2*np.pi*sigma**2)))*np.exp((-(x-mu)**2)/(2*sigma**2))

# %%
x = np.linspace(-6,6,1000)

# %%
mu = 0

# %%
sigma = 1

# %%
pdf = normal_pdf(x,mu,sigma) #Use Normal for demo, replace with custom function pdf

# %%
def partial_sums(x):

  y = np.zeros(x.shape)
  
  for n in range(x.shape[0]):
    
    y[n] = np.sum(x[0:n])
    
  y = y / np.max(y)
    
  return y

# %%
cdf = partial_sums(pdf)

# %%
plt.plot(x,cdf,'.');

# %%
d_cdf = cdf[1:] - cdf[0:-1] #Demo to show that the diff of the cdf gives you back the pdf
plt.plot(x[1:],d_cdf,'.');  #Not required for sampling

# %%
plt.plot(cdf,x,'.');

# %%
def find_nearest(array, value):

  idx = np.argmin(np.abs(array - value))
  
  return idx

# %%
find_nearest(cdf, 0.1)
# Out:
# 393

# %%
x[393]
# Out:
# -1.2792792792792795

# %%
xr = np.random.random((10000,))

# %%
w = np.zeros(xr.shape[0])

for i in range(xr.shape[0]):
  
  w[i] = x[find_nearest(cdf, xr[i])]

# %%
w.shape
# Out:
# (10000,)

# %%
plt.hist(w,50);  #The hist() function in pyplot module of matplotlib library is used to plot a histogram.

# %%
num_bins = 50
n,bins,patches = plt.hist(w, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)

# %% [markdown]
# # Random Color

# %%
#Import libraries 
import numpy as np
import matplotlib.pyplot as plt

# %%
z = np.random.randint(0,255,size=(1,1,3)) #creates an array of specified shape and fills it with random values.

# %%
z
# Out:
# array([[[113, 153,  74]]])

# %%
z = np.random.randint(0,255,size=(10,10,3))

# %%
plt.imshow(z)
 #The imshow() function in pyplot module of matplotlib library is used to display data as an image; i.e. on a 2D regular raster.

# %%
z = np.zeros((10,10,3))

# %%
z.shape
# Out:
# (10, 10, 3)

# %%
plt.imshow(z) 
#The imshow() function in pyplot module of matplotlib library is used to display data as an image; i.e. on a 2D regular raster.

# %%
z = 0*np.ones((10,10,3))

# %%
plt.imshow(z)
#The imshow() function in pyplot module of matplotlib library is used to display data as an image; i.e. on a 2D regular raster.

# %%
z = 255*np.ones((10,10,3))

# %%
plt.imshow(z)
#The imshow() function in pyplot module of matplotlib library is used to display data as an image; i.e. on a 2D regular raster.
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
z = np.ones((10,10,3))

z[:,:,0] = 1
z[:,:,1] = 0
z[:,:,2] = 0

plt.imshow(z) #The imshow() function in pyplot module of matplotlib library is used to display data as an image; i.e. on a 2D regular raster.

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 1
z[:,:,2] = 0

plt.imshow(z)

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 0
z[:,:,2] = 1

plt.imshow(z)

# %%
plt.hist(np.random.randn(1000,)/6 + 1/2)
# Out:
# (array([  3.,   7.,  29., 117., 169., 257., 218., 113.,  73.,  14.]),
#  array([-1.07740216e-01, -7.67002550e-04,  1.06206211e-01,  2.13179424e-01,
#          3.20152638e-01,  4.27125851e-01,  5.34099065e-01,  6.41072278e-01,
#          7.48045492e-01,  8.55018705e-01,  9.61991919e-01]),
#  <a list of 10 Patch objects>)

# %%
for _ in range(100):
    z = np.ones((10,10,3))

    r = np.random.randn()/6 + 1/2
    g = np.random.randn()/6 + 1/2
    b = np.random.randn()/6 + 1/2

    print(r,g,b)

    z[:,:,0] = r
    z[:,:,1] = g
    z[:,:,2] = b

    plt.imshow(z);
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0.5501784276191822 0.3265089440305261 0.518418637101116
# 0.5295770342442208 0.3537063069234877 0.535001464883995
# 0.5844172915774911 0.6253975607252701 0.5938565902193615
# 0.37655972719111724 -0.19180977165530644 0.4908662224546949
# 0.12090396570712025 0.37346390109266847 0.582603714793481
# 0.41783613760369137 0.4943146540642062 0.5195873016470328
# 0.4275141858129453 0.6303040309855706 0.6130486380490728
# 0.6314021326053897 0.9116295623785482 0.874092527815731
# 0.7903140013589462 0.25056397496372274 0.38288594656818953
# 0.6530771570241962 0.20215617514128253 0.5606953896082484
# 0.5866451020239629 0.4282154942309278 0.5115600963463016
# 0.3027769685107231 0.8796532022721579 0.1959191644482256
# ...

# %%
for i in range(100):

    z = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()

    print(r,g,b)

    z[:,:,0] = r
    z[:,:,1] = g
    z[:,:,2] = b

    plt.imshow(z);
    plt.show()
# Out:
# 0.09058764438069344 0.7176784928725832 0.6316086903044634
# 0.5079910429946529 0.24456007763287158 0.8189018159529496
# 0.5516011730453466 0.5347885586674578 0.6931599374645905
# 0.32628715978080713 0.8325025865273903 0.2797883563540765
# 0.07223861400361509 0.8230840372653082 0.587276928737575
# 0.7623078199085324 0.6332414515482516 0.8922731528514187
# 0.0008941222397338411 0.6045562252739102 0.5026399562528266
# 0.7934900583658314 0.14789429463114034 0.6372878856208003
# 0.9550488029803247 0.5829437666952452 0.21339954396727878
# 0.15224270490526515 0.6744823318937933 0.6219699610669717
# 0.9597901765225254 0.349996421577603 0.7510449040393227
# 0.3081848527196541 0.8780932607332294 0.221503800206875
# 0.20720664244667786 0.7206283561051767 0.653255207173325
# 0.23735768052774664 0.0714584555663429 0.3385525153555049
# 0.5439678337608536 0.3088383657781473 0.8457317582402698
# 0.0751710728634497 0.42105653733334947 0.038813004541548346
# ...

# %%
z1 = np.ones((10,10,3))
z1[:,:,0] = np.random.rand()
z1[:,:,1] = np.random.rand()
z1[:,:,2] = np.random.rand()

z2 = np.ones((10,10,3))
z2[:,:,0] = np.random.rand()
z2[:,:,1] = np.random.rand()
z2[:,:,2] = np.random.rand()

zavg = (z1+z2)/2

z1a = (z1+zavg)/2
z2a = (z2+zavg)/2

z3 = np.hstack((z1,z1a,zavg,z2a,z2))

plt.imshow(z3);
plt.show()

# %%
for i in range(100):
    
    z1 = np.ones((10,10,3))
    z1[:,:,0] = np.random.rand()
    z1[:,:,1] = np.random.rand()
    z1[:,:,2] = np.random.rand()

    z2 = np.ones((10,10,3))
    z2[:,:,0] = np.random.rand()
    z2[:,:,1] = np.random.rand()
    z2[:,:,2] = np.random.rand()

    zavg = (z1+z2)/2

    z1a = (z1+zavg)/2
    z2a = (z2+zavg)/2

    z3 = np.hstack((z1,z1a,zavg,z2a,z2))

    plt.imshow(z3);
    plt.show()

# %%
for i in range(100):
    
    z1 = np.ones((10,10,3))
    z2 = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()

    z1[:,:,0] = r
    z1[:,:,1] = g
    z1[:,:,2] = b
    
    z2[:,:,0] = 1-r
    z2[:,:,1] = 1-g
    z2[:,:,2] = 1-b

    z3 = np.hstack((z1,z2))

    plt.imshow(z3);
    plt.show()

# %% [markdown]
# https://lospec.com/palette-list

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib
import imageio
from PIL import Image

def get_colors_lospec(url):
    im = imageio.imread(url)
    rgb_list = (im/255)[0,:,0:3]
    float_list = list(np.linspace(0,1,len(rgb_list)))    
    cdict = dict()
    for num, col in enumerate(['red', 'green', 'blue']):
        col_list = [[float_list[i], rgb_list[i][num], rgb_list[i][num]] for i in range(len(float_list))]
        cdict[col] = col_list
    cmp = mcolors.LinearSegmentedColormap('my_cmp', segmentdata=cdict, N=256)
    return cmp

# %% [markdown]
# #URL (Uniform Resource Locator)

# %%
url = 'https://lospec.com/palette-list/agb-32x.png'  
#A URL (Uniform Resource Locator) is a unique identifier used to locate a resource on the Internet. 
#It is also referred to as a web address.

# %%
url = 'https://lospec.com/palette-list/agb-1x.png'
#A URL (Uniform Resource Locator) is a unique identifier used to locate a resource on the Internet. 
#It is also referred to as a web address.

# %%
url = 'https://lospec.com/palette-list/moondrom-1x.png'
#A URL (Uniform Resource Locator) is a unique identifier used to locate a resource on the Internet. 
#It is also referred to as a web address.

# %%
im = imageio.imread(url)

# %%
plt.imshow(im);
#The imshow() function creates an image from a 2-dimensional numpy array. 
#The image will have one square for each element of the array. 
#The color of each square is determined by the value of the corresponding array element and the color map used by imshow().

# %%
z = np.random.randint(0,255,size=(10,10))

# %%
plt.imshow(z, cmap=get_colors_lospec(url))
plt.colorbar();

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05] 
#The mgrid() function is used to get a dense multi-dimensional 'meshgrid'. 
#The purpose of meshgrid is to create a rectangular grid out of an array of x values and an array of y values.

z = np.sqrt(x**2 + y**2) #function is used to determine the positive square-root of an array, element-wise. 

plt.imshow(z, cmap=get_colors_lospec(url)); 
#creates an image from a 2-dimensional numpy array. 
#The image will have one square for each element of the array. 
#The color of each square is determined by the value of the corresponding array element and the color map used by imshow() .
plt.show() #The show() function in pyplot module of matplotlib library is used to display all figures.

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
#The mgrid() function is used to get a dense multi-dimensional 'meshgrid'. 
#The purpose of meshgrid is to create a rectangular grid out of an array of x values and an array of y values.

z = np.sin(3*y) 
#This mathematical function helps user to calculate trigonometric sine for all x(being the array elements).
#The np. sin() function help to find sine value of the angle in degree and radian.

plt.imshow(z, cmap=get_colors_lospec(url));
#creates an image from a 2-dimensional numpy array. 
#The image will have one square for each element of the array. 
#The color of each square is determined by the value of the corresponding array element and the color map used by imshow() .
plt.show() #The show() function in pyplot module of matplotlib library is used to display all figures.

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
#The mgrid() function is used to get a dense multi-dimensional 'meshgrid'. 
#The purpose of meshgrid is to create a rectangular grid out of an array of x values and an array of y values.

z = np.sin(3*y)*np.sin(3*x)
#This mathematical function helps user to calculate trigonometric sine for all x(being the array elements).
#The np. sin() function help to find sine value of the angle in degree and radian.

plt.imshow(z, cmap=get_colors_lospec(url));
#creates an image from a 2-dimensional numpy array. 
#The image will have one square for each element of the array. 
#The color of each square is determined by the value of the corresponding array element and the color map used by imshow() .
plt.show()
#creates an image from a 2-dimensional numpy array. 
#The image will have one square for each element of the array. 
#The color of each square is determined by the value of the corresponding array element and the color map used by imshow() .
