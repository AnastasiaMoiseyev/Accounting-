# %% [markdown]
# <a href="https://colab.research.google.com/github/AnastasiaMoiseyev/STA2023_Fall_2022/blob/main/Anastasia_Stats_2023_Lab_6_Cereal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lab 6

# %%
import numpy as np #imports numpy. to use numpy, use"np". i.e."np.random.randn"
import matplotlib.pyplot as plt  #imports matplotlib.pyplot. to use it, use "plt.plot(x,y,'r.')"
import pandas as pd #imports pandas. "pd" to use
import urllib.request  #defines functions and classes which help in opening URLs (mostly HTTP) in a complex world — basic and digest authentication, redirections, cookies and more.

# %%
urllib.request.urlretrieve('https://raw.githubusercontent.com/williamedwardhahn/Probability_Statistics/main/cereal_data.csv','cereal_data.csv')

#The urllib.request.urlretrieve() function is used to retrieve the image from the given URL and store it in the required file directory.

#The urlretrieve() method downloads the remote data directly to the local. 
#The parameter filename specifies the save local path (if the parameter is not specified, urllib will generate a temporary file to save the data.)
# Out:
# ('cereal_data.csv', <http.client.HTTPMessage at 0x7ff5cdf63130>)

# %%
cereal_data = pd.read_csv('cereal_data.csv')  
#The pd.read_csv() function takes a path to a CSV file and reads the data into a Pandas DataFrame object.

#pd.read_csv ->  Read a comma-separated values (csv) file into DataFrame. Also supports optionally iterating or breaking the file into chunks.

# %% [markdown]
# Name: Name of cereal
#
# mfr: Manufacturer of cereal
#
#     A = American Home Food Products
#
#     G = General Mills
#
#     K = Kelloggs
#
#     N = Nabisco
#
#     P = Post
#
#     Q = Quaker Oats
#
#     R = Ralston Purina
#
# type:
#
#     cold
#
#     hot
#
# calories: calories per serving
#
# protein: grams of protein
#
# fat: grams of fat
#
# sodium: milligrams of sodium
#
# fiber: grams of dietary fiber
#
# carbo: grams of complex carbohydrates
#
# sugars: grams of sugars
#
# potass: milligrams of potassium
#
# vitamins: vitamins and minerals - 0, 25, or 100,
# indicating the typical percentage of FDA recommended
#
# shelf: display shelf (1, 2, or 3, counting from the floor)
#
# weight: weight in ounces of one serving
#
# cups: number of cups in one serving
#
# rating: a rating of the cereals

# %%
cereal_data
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
cereal_data["sugars"].mean()
# Out:
# 6.922077922077922

# %%
cereal_data[["calories", "sugars"]].mean()
# Out:
# calories    106.883117
# sugars        6.922078
# dtype: float64

# %%
cereal_data.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
cereal_data[["calories", "sugars"]]
# Out:
#     calories  sugars
# 0         70       6
# 1        120       8
# 2         70       5
# 3         50       0
# 4        110       8
# ..       ...     ...
# 72       110       3
# 73       110      12
# 74       100       3
# 75       100       3
# 76       110       8
#
# [77 rows x 2 columns]

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["calories"]],'.') 
#The plot() function is used to make a 2D hexagonal binning plot of points x, and y.

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.')

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.')

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["carbo"]],'.')

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["vitamins"]],'.')

# %%
#We pointed out that x and y.
X = cereal_data[["sugars"]]
Y = cereal_data[["calories"]]

# %%
from sklearn.linear_model import LinearRegression  
linear_regressor = LinearRegression() 

#Linear regression is a basic and commonly used type of predictive analysis.

#Linear regression is a statistical method for modeling relationships between a dependent variable with a given set of independent variables.

#Linear regression uses the relationship between the data points to draw a straight line through all of them. This line can be used to predict future values.

# %%
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X)

# %%
plt.plot(X, Y,'.')
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
 #In the above figure,
#X-axis = Independent variable

#Y-axis = Output / dependent variable

#Line of regression = Best fit line for a model

# %%
import numpy as np #imports numpy. to use numpy, use"np". i.e."np.random.randn"
import matplotlib.pyplot as plt #imports matplotlib.pyplot. to use it, use "plt.plot(x,y,'r.')"

# %%
x = np.linspace(0,10,50) 
# np.linspace is a tool in Python for creating numeric sequences.

#It is somewhat similar to the np.arange function, in that it creates sequences of evenly spaced numbers structured as a np.array

#The linspace function generates linearly spaced vectors.

# %%
noise = 10 * np.random.randn(50,)

# %%
y = 3 * x + 7 + noise

# %%
plt.plot(x,y,'.');

# %%
m_guess = 1
b_guess = 1

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
m_guess = 5
b_guess = 15

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
m_guess = 3
b_guess = 7

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
loss = np.sum((y_guess - y)**2)

# %%
loss
# Out:
# 4143.9067444989505

# %%
for m_guess in np.linspace(-10,10,10):
    for b_guess in np.linspace(-10,10,10):
        
        y_guess = m_guess * x + b_guess

        plt.plot(x,y_guess,'r.');
        plt.plot(x,y,'g.');
        plt.show()

        loss = np.sum((y_guess - y)**2)

        print(loss,m_guess,b_guess)
# Out:
# 430873.4822203997 -10.0 -10.0
# 412511.0053874351 -10.0 -7.777777777777778
# 394642.35571496433 -10.0 -5.555555555555555
# 377267.5332029874 -10.0 -3.333333333333333
# 360386.5378515043 -10.0 -1.1111111111111107
# 343999.3696605149 -10.0 1.1111111111111107
# 328106.02863001946 -10.0 3.333333333333334
# 312706.51476001774 -10.0 5.555555555555557
# 297800.8280505099 -10.0 7.777777777777779
# 283388.96850149595 -10.0 10.0
# 320579.6190821005 -7.777777777777778 -10.0
# 304686.2780516051 -7.777777777777778 -7.777777777777778
# 289286.7641816034 -7.777777777777778 -5.555555555555555
# 274381.07747209555 -7.777777777777778 -3.333333333333333
# 259969.21792308157 -7.777777777777778 -1.1111111111111107
# 246051.1855345614 -7.777777777777778 1.1111111111111107
# 232626.98030653506 -7.777777777777778 3.333333333333334
# 219696.6022390025 -7.777777777777778 5.555555555555557
# 207260.0513319638 -7.777777777777778 7.777777777777779
# 195317.327585419 -7.777777777777778 10.0
# ...

# %%
best_loss = 100000
best_m = 0
best_b = 0 

for m_guess in np.linspace(-10,10,20):
    for b_guess in np.linspace(-10,10,20):
        
        y_guess = m_guess * x + b_guess

        loss = np.sum((y_guess - y)**2)

        if loss < best_loss:
            
            best_loss = loss
            best_m = m_guess
            best_b = b_guess 

            plt.plot(x,y_guess,'r.');
            plt.plot(x,y,'g.');
            plt.show()

            print(loss,m_guess,b_guess)
# Out:
# 98918.1006298776 -3.6842105263157894 3.6842105263157894
# 94923.07082195746 -3.6842105263157894 4.7368421052631575
# 91038.84433813702 -3.6842105263157894 5.789473684210526
# 87265.42117841633 -3.6842105263157894 6.842105263157894
# 83602.80134279537 -3.6842105263157894 7.894736842105264
# 80050.98483127411 -3.6842105263157894 8.94736842105263
# 76609.97164385256 -3.6842105263157894 10.0
# 74189.79796141271 -2.6315789473684212 3.6842105263157894
# 70748.78477399118 -2.6315789473684212 4.7368421052631575
# 67418.57491066937 -2.6315789473684212 5.789473684210526
# 64199.16837144728 -2.6315789473684212 6.842105263157894
# 61090.56515632492 -2.6315789473684212 7.894736842105264
# 58092.76526530229 -2.6315789473684212 8.94736842105263
# 55205.76869837937 -2.6315789473684212 10.0
# 53192.62763508135 -1.578947368421053 3.6842105263157894
# 50305.63106815844 -1.578947368421053 4.7368421052631575
# 47529.43782533525 -1.578947368421053 5.789473684210526
# ...
